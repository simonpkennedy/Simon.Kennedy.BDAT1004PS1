# %% [markdown]
# Problem Set 1
# # Question 1
#
# What are the data types?

# %% [markdown]
# 5                integer
# 5.0              double
# 5 > 1            boolean
# '5'              character
# 5 * 2            integer
# '5' * 2          string
# '5' + '2'        string
# 5 / 2            double
# 5 % 2            double
# {5, 2, 1}        array
# 5 == 3           boolean
# Pi (the number)  double

# %% [markdown]
# # Question 2
# a. Write and evaluate C# expressions.

# %% [markdown]
#     String a = "Supercalifragilisticexpialidocious";
#             Console.WriteLine(a.Length);
#             Console.ReadLine();

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Question2
# b. Write and evaluate C# expressions.

# %% [markdown]
#   String a= "Supercalifragilisticexpialidocious";
#
#             if (a.Contains ("ice"))
#             {
#                 Console.WriteLine("The string containes the string ice");
#             }
#
#             Console.ReadLine();

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Question 2
# c. Write and evaluate C# expressions.

# %% [markdown]
# string a = "Supercalifragilisticexpialidocious";
#  string b = "Honorificabilitudinitatibus";
#  string c = "Bababadalgharaghtakamminarronnkonn";
#            {
#                if (a > b)
#                    {
#                         if (a>c)
#                         {
#                               Console.WriteLine("{0} is the largest", a);
#                         }
#                         else
#                         {
#                                Console.WriteLine("{0} is the largest", c);
#                         }
#                    }
#                    else
#                    {
#                         if (b>c)
#                         {
#                               Console.WriteLine("{0} is the largest", b);
#                         }
#                         else
#                        {
#                                Console.WriteLine("{0} is the largest", c);
#                        }
#                    }
#
#            }
# /* I tried to use the example from the Week 2 Lecture here to try to compare the strings*/

# %% [markdown]
# # Question 2
# d. Write and evaluate C# expressions.

# %% [markdown]
#     string[] a = new string[] {"Berlioz", "Borodin", "Brian", "Bartok",
#                                         "Bellini", "Buxtehude", "Bernstein"};
#             Array.Sort(a);
#
#             foreach (string name in a)
#             Console.WriteLine(name);
#             {
#                 Console.ReadLine();
#             }

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Question 3
# Return triangle area.

# %% [markdown]
#  Console.WriteLine("Enter the length of Triangle side 1: ");
#
#      Console.Readline (int[0]);
#
#  Console.WriteLine("Enter the length of Triangle side 2: ");
#
#      Console.Readline (int[1]);
#
#  Console.WriteLine("Enter the length of Triangle side 3: ");
#
#      Console.Readline (int[2])
#
#
#
#  Console.WriteLine

# %% [markdown]
# # Question 4
# Separate odd and even integers in arrays.

# %% [markdown]
# int[] myarray =new int[]{25,47,42,56,32};
#             foreach	(int i in myarray)
#             {
#                 Console.WriteLine("The Even elements are: "lst );
#                 COnsole.WriteLine("The Odd elements ar: "lst);
#                 }

# %% [markdown]
# # Question 5
# a. Write the function inside()

# %% [markdown]
# Apologies Ethan but I don't understand what is being asked here. So Sorry.

# %% [markdown]
# # Question 5
# b. Use function inside() in expression.

# %% [markdown]
# # Question 6
# Return pig-Latin

# %%
word = input('Enter a word: ')
    if char(0)!=(a, e, i, o, u)
    then
print('Your word in pig-Latin is: ' word.lower[1:n][0] + 'ay')
    if char(0)=(a, e, i, o, u)
    then
print('Your word in pig-Latin is: 'word.lower [0:] + 'way')
# Out:
#   File "<ipython-input-5-26bf16bb5aed>", line 2
#     if char(0)!=(a, e, i, o, u)
#                                ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Question 7
# Number of patients with each bloodtype.

# %%
infile = open('bloodtype1.txt', r)
infile.read(n)

    Bldcount()

# %% [markdown]
# # Question 8
# Curconv Function.

# %% [markdown]
# # Question 9
# Exception types.

# %% [markdown]
# Trying to add incompatible variables, as in
# adding 6 + ‘a’
#
# This would generate a TypeError.
#
# Referring to the 12th item of a list that has only 10
# items
#
# This would generate an IndexError.
#
# Using a value that is out of range for a function’s
# input, such as calling math.sqrt(-1.0)
#
# This would geberate an IOError.
#
# Using an undeclared variable, such as print(x)
# when x has not been defined
#
# This would generate a NameError.
#
# Trying to open a file that does not exist, such as
# mistyping the file name or looking in the wrong
# directory.
#
# This would generate an IOError.

# %% [markdown]
# # Question 10
# Frequencies function.

# %%
 string letters = "abcdefghijklmnopqrstuvwxyz"
    myFunction frequencies()
